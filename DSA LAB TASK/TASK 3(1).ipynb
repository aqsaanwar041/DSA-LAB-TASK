# %%
TASK 3 (1)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        curr = self.head
        while curr.next:
            curr = curr.next
        curr.next = new_node

    def insert_at_position(self, data, position):
        if position < 1:
            raise ValueError("Position must be >= 1")
        if position == 1:
            self.insert_at_beginning(data)
            return
        new_node = Node(data)
        curr = self.head
        for _ in range(position - 2):
            if not curr:
                raise IndexError("Position out of bounds")
            curr = curr.next
        if not curr:
            raise IndexError("Position out of bounds")
        new_node.next = curr.next
        curr.next = new_node

    def delete_by_value(self, data):
        if not self.head:
            return False
        if self.head.data == data:
            self.head = self.head.next
            return True
        curr = self.head
        while curr.next and curr.next.data != data:
            curr = curr.next
        if curr.next:
            curr.next = curr.next.next
            return True
        return False

    def search(self, data):
        curr = self.head
        position = 1
        while curr:
            if curr.data == data:
                return position
            curr = curr.next
            position += 1
        return -1  # Not found

    def display(self):
        values = []
        curr = self.head
        while curr:
            values.append(str(curr.data))
            curr = curr.next
        return " → ".join(values) if values else "Empty List"

# %%
def test_singly_linked_list():
    sll = SinglyLinkedList()
    sll.insert_at_beginning(3)
    sll.insert_at_beginning(2)
    sll.insert_at_beginning(1)
    assert sll.display() == "1 → 2 → 3"
    sll.insert_at_end(4)
    sll.insert_at_end(5)
    assert sll.display() == "1 → 2 → 3 → 4 → 5"
    sll.insert_at_position(9, 3)  
    assert sll.display() == "1 → 2 → 9 → 3 → 4 → 5"
    sll.delete_by_value(9)
    assert sll.display() == "1 → 2 → 3 → 4 → 5"
    sll.delete_by_value(1)
    assert sll.display() == "2 → 3 → 4 → 5"
    sll.delete_by_value(5)
    assert sll.display() == "2 → 3 → 4"
    assert sll.search(3) == 2
    assert sll.search(10) == -1

    print("All test cases passed.")
test_singly_linked_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      19     assert sll.search(10) == -1
#      21     print("All test cases passed.")
# ---> 22 test_singly_linked_list()
#
# Cell In[1], line 2, in test_singly_linked_list()
#       1 def test_singly_linked_list():
# ----> 2     sll = SinglyLinkedList()
#       3     sll.insert_at_beginning(3)
#       4     sll.insert_at_beginning(2)
#
# NameError: name 'SinglyLinkedList' is not defined
